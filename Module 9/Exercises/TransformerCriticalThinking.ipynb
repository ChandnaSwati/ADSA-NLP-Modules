# %% [markdown]
# You have already been given a working Transformer implementation.
#
# Your task is **NOT simply to run the code**.
#
# Your task is to investigate:
#
# - Why does the Transformer work?
# - Which components are important?
# - What happens if we modify the architecture?
# - When would we choose a Transformer over an RNN or FFNN?
#
# You should behave like an AI engineer and researcher rather than a programmer.
#
#
#
# # Part 1 – Architecture Detective
#
# Study the Transformer code.
#
# ## Task 1
#
# Locate the following components in the code:
#
# - Token Embedding
# - Positional Embedding
# - Multi-Head Attention
# - Feed Forward Network
# - Add & Normalize
# - Output Layer
#
# ## Task 2
#
# Create a diagram showing the flow of data through the model.
#
# ## Task 3
#
# For each component explain:
#
# - What does it do?
# - Why is it needed?
# - What might happen if it is removed?
#
#
#
# # Part 2 – Predict Before Running
#
# Before training the model:
#
# ## Predict:
# 1. Will the model achieve 50%, 70%, 90%, or 100% accuracy?
# 2. Which words do you think the model will learn as strong positive indicators?
# 3. Which words do you think the model will learn as strong negative indicators?
#
# Create a table:
#
# | Positive Indicators | Negative Indicators |
# |--------------------|--------------------|
# |                    |                    |
# |                    |                    |
# |                    |                    |
#
# Run the model afterwards and compare your predictions with the actual results.
#
#
#
# # Part 3 – Transformer Surgery
#
# Modify ONE component at a time.
# Predict the effect BEFORE running.
# Then test your hypothesis.
#
#
#
# ## Experiment A: Remove Positional Embedding
#
# Comment out:
#
# ```python
# return token_emb + position_emb
# ```
#
# Replace with:
#
# ```python
# return token_emb
# ```
#
# ### Questions
#
# 1. What do you expect to happen?
# 2. Does accuracy change?
# 3. Why?
#
# ### Discussion
#
# Would word order still matter?
#
#
#
# ## Experiment B: Remove Multi-Head Attention
#
# Replace:
#
# ```python
# x = TransformerBlock(...)
# ```
#
# with:
#
# ```python
# x = Dense(...)
# ```
#
# ### Questions
#
# 1. Is this still a Transformer?
# 2. What information is lost?
# 3. How does performance change?
#
#
# ## Experiment C: Remove Residual Connections
#
# Replace:
#
# ```python
# inputs + attention_output
# ```
#
# with:
#
# ```python
# attention_output
# ```
#
# and
#
# ```python
# out1 + ffn_output
# ```
#
# with:
#
# ```python
# ffn_output
# ```
#
# ### Questions
#
# 1. Why were residual connections added?
# 2. Does the model become harder to train?
# 3. Why?
#
#
#
# # Part 4 – Hyperparameter Challenge
#
# Your have limited computing resources.
#
# You must recommend a configuration.
#
# Test:
#
# ## Number of Heads
#
# ```python
# 1
# 2
# 4
# 8
# ```
#
# ## Embedding Dimension
#
# ```python
# 8
# 16
# 32
# 64
# ```
#
# Create a table:
#
# | Heads | Embedding Dim | Accuracy | Training Time |
# |--------|--------------|----------|--------------|
# |        |              |          |              |
# |        |              |          |              |
# |        |              |          |              |
#
# ### Discussion
#
# 1. Does bigger always mean better?
# 2. Which configuration would you deploy?
# 3. Why?
#
#
#
# # Part 5 – Build Your Own Review Dataset (20 min)
#
# Create at least:
#
# - 10 positive reviews
# - 10 negative reviews
#
# that are NOT used previously.
#
# Examples:
#
# ```text
# Amazing soundtrack and story
# ```
#
# ```text
# The movie was painfully slow
# ```
#
# Train the model again.
#
# ### Questions
#
# 1. Does accuracy increase or decrease?
# 2. Why?
# 3. What types of reviews confuse the model?
#
#
#
# # Part 6 – Fool the Transformer
#
# Try to break the model.
#
# Create sentences such as:
#
# ```text
# The movie was not bad
# ```
#
# ```text
# The movie was not good
# ```
#
# ```text
# The acting was good but the story was terrible
# ```
#
# ```text
# The film was surprisingly not awful
# ```
#
# ### Questions
#
# 1. Which examples are classified incorrectly?
# 2. Why might the model struggle?
# 3. How could we improve it?
#
#
#
# # Part 7 – Think Beyond Sentiment Analysis
#
# The Transformer is currently used for sentiment analysis.
#
# Brainstorm in pairs:
#
# ### Could the same architecture be adapted for:
#
# - Resume matching
#
#
# For each application discuss:
#
# 1. Required data
# 2. Potential benefits
# 3. Risks and ethical concerns
#
# ---
#
# # Part 8 – Critical Thinking Challenge
#
# ## Question 1
#
# If Transformers are so powerful, why do RNNs and LSTMs still exist?
#
#
# ## Question 2
#
# Would a Transformer always outperform an RNN on a very small dataset?
#
# Why or why not?
#
#
# ## Question 3
#
# If you remove positional encoding, can the Transformer still understand:
#
# ```text
# Dog bites man
# ```
#
# versus
#
# ```text
# Man bites dog
# ```
#
# Explain.
#
#
# ## Question 4
#
# What is the biggest limitation of Transformers?
#
# Consider:
#
# - Memory usage
# - Computational cost
# - Environmental impact
# - Bias
#
#
# ## Question 5
#
# Modern LLMs contain billions of parameters.
#
# Do more parameters automatically mean more intelligence?
#
# Defend your answer.
#
#
# # Bonus Challenge
#
# Implement one of the following:
#
# ### Option A
#
# Add a second Transformer block:
#
# ```python
# x = TransformerBlock(embed_dim, num_heads, ff_dim)(x)
# x = TransformerBlock(embed_dim, num_heads, ff_dim)(x)
# ```
#
# Analyze the effect.
#
# ### Option B
#
# Create a multiclass sentiment classifier:
#
# - Positive
# - Neutral
# - Negative
#
#
#
# # Part 9 – Become the Architect (In groups)
#
# Design a new Transformer-based application.
#
# Choose one domain:
#
# - Healthcare
# - Finance
# - Education
# - Logistics
# - Sustainability
# - Gaming
# - Social Media
#
# Create a proposal describing:
#
# 1. Problem statement
# 2. Input data
# 3. Expected output
# 4. Why a Transformer is suitable
# 5. Possible challenges
# 6. Ethical considerations
#
# Present your idea in next lecture.
