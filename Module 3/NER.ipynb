# %%
# Import spaCy
import spacy

# Load English NLP model
nlp = spacy.load("en_core_web_sm")

# Example text
text = "Apple opened a new office in Berlin in 2024."

# Process the text
doc = nlp(text)

# Print named entities
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Apple ORG
# Berlin GPE
# 2024 DATE

# %%
print(f"{'Entity':<20} {'Label':<10} {'Explanation'}")
print("-" * 50)

for ent in doc.ents:
    print(f"{ent.text:<20} {ent.label_:<10} {spacy.explain(ent.label_)}")
# Out:
# Entity               Label      Explanation
# --------------------------------------------------
# Apple                ORG        Companies, agencies, institutions, etc.
# Berlin               GPE        Countries, cities, states
# 2024                 DATE       Absolute or relative dates or periods

# %%
from spacy import displacy
from IPython.display import HTML, display

# Create NER visualization as HTML
html = displacy.render(doc, style="ent", jupyter=False)

# Display it safely in Jupyter
display(HTML(html))
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  opened a new office in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Berlin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2024
# ...

# %%
text = """
Microsoft announced that it will invest 3 billion euros in Germany by 2026.
The project will support AI research in Berlin and Munich.
Satya Nadella said the company wants to expand cloud infrastructure in Europe.
"""

# 1. Identify all named entities.
# 2. Write their labels.
# 3. Explain what each label means.
# 4. Check if spaCy detects all entities correctly.
# 5. Discuss which entities are missed or wrongly classified.
