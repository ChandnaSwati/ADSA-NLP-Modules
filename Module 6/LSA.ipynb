# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

docs = [
    "Deep learning uses neural networks",
    "Machine learning models need data",
    "Statistics is essential for data analysis"
]

vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(docs)

lsa = TruncatedSVD(n_components=2)
lsa_output = lsa.fit_transform(X)

terms = vectorizer.get_feature_names_out()
for i, comp in enumerate(lsa.components_):
    terms_in_topic = comp.argsort()[-6:]
    print(f"\nTopic {i}:")
    print([terms[j] for j in terms_in_topic])
# Out:
# Topic 0:
# ['analysis', 'machine', 'models', 'need', 'learning', 'data']
#
# Topic 1:
# ['need', 'learning', 'deep', 'networks', 'neural', 'uses']
