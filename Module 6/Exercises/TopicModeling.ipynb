# %%
# TOPIC MODELING EXERCISE


# 1. Import Libraries
# Hint: You may need: PyPDF2 or pdfplumber, nltk/spacy, sklearn, bertopic
# Example:
# import pdfplumber
# from sklearn.feature_extraction.text import TfidfVectorizer


# 2. Load PDF and Extract Text
# Hint: Use pdfplumber.open("myfile.pdf") and read page.text


# 3. Preprocess Text
# Hint: Use nltk stopwords or spaCy's nlp() pipeline
# spaCy example:
# import spacy
# nlp = spacy.load("en_core_web_sm")
# doc = nlp(text)


# 4. TF-IDF Matrix
# Hint:
# vectorizer = TfidfVectorizer(stop_words='english')
# X = vectorizer.fit_transform(cleaned_docs)


# 5. NMF
# Hint: from sklearn.decomposition import NMF
# nmf = NMF(n_components=3)
# W = nmf.fit_transform(X)
# H = nmf.components_


# 6. LSA (SVD)
# Hint: from sklearn.decomposition import TruncatedSVD
# svd = TruncatedSVD(n_components=3)
# lsa_matrix = svd.fit_transform(X)


# 7. BERTopic
# Hint:
# from bertopic import BERTopic
# model = BERTopic(language="english")
# topics, probs = model.fit_transform(cleaned_docs)
# model.get_topic_info()


# 8. Reflection
# Consider: clarity of topics, overlap, interpretability
