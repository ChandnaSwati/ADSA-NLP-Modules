# %% [markdown]
# # NLP Embedding Challenge
# ## Designing an AI-Powered Talent Matching System
# ---
#
# # Business Scenario
#
# A multinational company receives thousands of internship and job applications every year.
#
# The company wants to develop an NLP-based talent matching system that automatically recommends the most suitable positions for applicants.
#
# However, management is unsure whether the system should use:
#
# - TF-IDF
# - Word2Vec
# - GloVe
# - FastText
#
# Your consulting team has been hired to investigate and provide a recommendation.
#
# ### Important
#
# You are **NOT** asked to build the perfect recruitment system.
#
# Your objective is to determine:
#
# > Which embedding approach should be used and under what conditions?
#
# You must support your recommendation using experiments, analysis, and critical evaluation.
#
# ---
#
# # Available Job Positions
#
# ```python
# jobs = {
#
# "AI Engineer":
# """
# Large language models, machine learning,
# deep learning, neural networks,
# generative AI, retrieval augmented generation,
# AI agents, model deployment and MLOps.
# """,
#
# "Data Engineer":
# """
# Cloud infrastructure, ETL pipelines,
# data lakes, distributed systems,
# SQL, NoSQL, Spark, Airflow,
# data architecture and scalability.
# """,
#
# "Business Intelligence Analyst":
# """
# Dashboard design, KPIs,
# Tableau, Power BI,
# business reporting,
# decision support and storytelling.
# """,
#
# "Sustainability Analyst":
# """
# ESG reporting,
# environmental monitoring,
# sustainability metrics,
# climate risk assessment
# and environmental policy analysis.
# """,
#
# "Supply Chain Analyst":
# """
# Demand forecasting,
# inventory optimization,
# transportation planning,
# operations research,
# logistics analytics and procurement.
# """,
#
# "Biomedical AI Specialist":
# """
# Medical imaging,
# diagnostic systems,
# computer vision,
# healthcare analytics,
# deep learning and radiology.
# """
# }
# ```
#
# ---
#
# # Applicant Profiles
#
# ```python
# applicants = {
#
# "A1":
# """
# I enjoy building conversational AI systems,
# working with transformers and deploying
# machine learning models.
# """,
#
# "A2":
# """
# I have experience in cloud computing,
# data warehousing and designing scalable
# data infrastructures.
# """,
#
# "A3":
# """
# I enjoy analyzing climate indicators,
# environmental risks and sustainability reporting.
# """,
#
# "A4":
# """
# I like creating dashboards and translating
# complex business information into visual stories.
# """,
#
# "A5":
# """
# I am interested in medical imaging,
# computer vision and healthcare applications.
# """
# }
# ```
#
# ---
#
# # Phase 1 – Human Benchmark
#
# Before implementing any NLP model, perform a manual recommendation exercise.
#
# ## Task
#
# For every applicant:
#
# 1. Recommend the most suitable job position.
# 2. Justify your recommendation.
# 3. Assign a confidence score between 1 and 5.
#
# ### Deliverable
#
# | Applicant | Recommended Position | Confidence (1–5) | Justification |
# |------------|------------|------------|------------|
# | A1 | | | |
# | A2 | | | |
# | A3 | | | |
# | A4 | | | |
# | A5 | | | |
#
# ---
#
# ## Reflection Questions
#
# 1. Did all team members choose the same recommendation?
# 2. Which applicant was easiest to classify?
# 3. Which applicant was most ambiguous?
# 4. Which keywords influenced your decision?
# 5. Can multiple recommendations be correct?
#
# ---
#
# # Phase 2 – Embedding-Based Matching
#
# Implement the following approaches:
#
# 1. TF-IDF
# 2. Word2Vec
# 3. GloVe
# 4. FastText
#
# ---
#
# ## Task
#
# For each approach:
#
# 1. Create document embeddings for job descriptions.
# 2. Create embeddings for applicant profiles.
# 3. Compute cosine similarity.
# 4. Rank all job positions for each applicant.
#
# ---
#
# ## Expected Output
#
# ### Example
#
# Applicant A1
#
# | Rank | Position | Similarity |
# |--------|--------|--------|
# | 1 | AI Engineer | 0.84 |
# | 2 | Data Engineer | 0.52 |
# | 3 | BI Analyst | 0.19 |
# | 4 | Sustainability Analyst | 0.12 |
#
# Repeat for all applicants and all embedding approaches.
#
# ---
#
# ## Analysis Questions
#
# 1. Which recommendations are identical across all methods?
# 2. Which recommendations differ?
# 3. Which method produces the most intuitive rankings?
# 4. Which method produces surprising recommendations?
# 5. Which method appears most robust?
#
# ---
#
# # Phase 3 – Adversarial Testing
#
# Real-world applicants do not always use standard terminology.
#
# Modify the applicant profiles intentionally.
#
# ---
#
# ## Synonym Replacement
#
# Replace:
#
# | Original | Replacement |
# |----------|----------|
# | machine learning | predictive modelling |
# | chatbot | conversational assistant |
# | large language model | LLM |
# | business intelligence | BI |
#
# ---
#
# ## Spelling Errors
#
# Replace:
#
# | Original | Replacement |
# |----------|----------|
# | sustainability | sustainabilty |
# | database | datbase |
#
# ---
#
# ## Task
#
# Repeat Phase 2 using the modified profiles.
#
# ---
#
# ## Analysis Questions
#
# 1. Which methods are most affected?
# 2. Which recommendations change?
# 3. Which embedding handles synonyms best?
# 4. Which embedding handles spelling errors best?
# 5. Why does FastText behave differently?
# 6. Is TF-IDF still useful in this scenario?
#
# ---
#
# # Phase 4 – Ambiguous Candidates
#
# Create three new candidate profiles that could fit multiple jobs.
#
# ---
#
# ## Example Candidate
#
# ```text
# I enjoy using AI to solve business problems
# and presenting findings to stakeholders.
# ```
#
# ---
#
# ## Task
#
# Create two additional ambiguous profiles.
#
# For each profile:
#
# 1. Generate rankings using all four embeddings.
# 2. Compare recommendations.
#
# ---
#
# ## Discussion Questions
#
# 1. Which position should be recommended?
# 2. Is there only one correct answer?
# 3. Which embedding handles ambiguity best?
# 4. Should the system recommend multiple jobs?
# 5. Should recruiters see only the top recommendation?
#
# ---
#
# # Phase 5 – Explainability
#
# For every recommendation generate an explanation.
#
# ---
#
# ## Example
#
# ### Recommended Position
#
# AI Engineer
#
# ### Evidence
#
# - transformers
# - deployment
# - machine learning
#
# ### Similarity Score
#
# 0.84
#
# ### Explanation
#
# The applicant profile contains concepts strongly associated with AI Engineer responsibilities, including transformer models, deployment workflows, and machine learning applications.
#
# ---
#
# ## Compare Explainability
#
# Evaluate:
#
# ### TF-IDF
#
# - Easy to explain?
# - Which keywords drove the decision?
#
# ### Word2Vec
#
# - Can recommendations be justified clearly?
# - Are semantic matches transparent?
#
# ### FastText
#
# - How easily can recruiters understand the recommendation?
#
# ### GloVe
#
# - Is the recommendation interpretable?
#
# ---
#
# ## Reflection Questions
#
# 1. Which method provides the most transparent recommendations?
# 2. Which method would HR trust?
# 3. Which method would applicants trust?
# 4. Is explainability more important than accuracy?
#
# ---
#
# # Phase 6 – Fairness Investigation
#
# Consider the following alternative applicant descriptions.
#
# ---
#
# ### Version A
#
# ```text
# Recent graduate
# ```
#
# ### Version B
#
# ```text
# Junior professional
# ```
#
# ---
#
# ### Version C
#
# ```text
# Worked on university projects
# ```
#
# ### Version D
#
# ```text
# Worked on personal projects
# ```
#
# ---
#
# ## Questions
#
# 1. Could wording influence recommendations?
# 2. Could embeddings inherit historical biases?
# 3. Is semantic similarity always fair?
# 4. Could certain groups be disadvantaged?
# 5. Should the system ignore some profile information?
#
# ---
#
# ## Audit Design
#
# Design a fairness audit.
#
# Consider:
#
# - Different educational backgrounds
# - Different writing styles
# - Different levels of English proficiency
# - Different terminology usage
#
# ---
#
# # Phase 7 – Evaluation Design
#
# Management asks:
#
# > How do we know the recommender works?
#
# Design a complete evaluation strategy.
#
# ---
#
# ## Available Metrics
#
# ### Quantitative
#
# - Precision@K
# - Recall@K
# - Mean Reciprocal Rank (MRR)
# - Top-1 Accuracy
#
# ### Human Evaluation
#
# - Recruiter validation
# - HR review
# - Expert judgement
#
# ### User Evaluation
#
# - Applicant satisfaction
# - Recommendation usefulness
# - Recommendation trust
#
# ### Experimental Evaluation
#
# - A/B Testing
# - Online deployment experiments
#
# ---
#
# ## Task
#
# Select appropriate metrics and justify:
#
# 1. Why is the metric useful?
# 2. What does it measure?
# 3. What are its limitations?
#
# ---
#
# # Phase 8 – System Redesign
#
# You are now allowed to build a hybrid recommendation system.
#
# Available components:
#
# - TF-IDF
# - Word2Vec
# - GloVe
# - FastText
# - Skill extraction
# - Keyword matching
# - Rule-based filters
# - Domain-specific dictionaries
#
# ---
#
# ## Task
#
# Design a scoring function.
#
# ### Example
#
# ```text
# Final Score =
# 40% Semantic Similarity
# 30% Skill Matching
# 20% Keyword Overlap
# 10% Recruiter Rules
# ```
#
# ---
#
# ## Justification
#
# Explain:
#
# 1. Why each component is included.
# 2. Why each weight was selected.
# 3. What weaknesses remain.
# 4. How the system handles adversarial inputs.
#
# ---
#
# # Phase 9 – Executive Recommendation
#
# Prepare a 5-minute presentation for senior management.
#
# ---
#
# ## Question 1
#
# Which embedding should be deployed?
#
# ---
#
# ## Question 2
#
# Why?
#
# Support your answer with:
#
# - Experimental results
# - Evaluation metrics
# - Error analysis
#
# ---
#
# ## Question 3
#
# Where will the chosen method fail?
#
# Examples:
#
# - Synonyms
# - New terminology
# - Misspellings
# - Domain-specific language
# - Ambiguous applicants
#
# ---
#
# ## Question 4
#
# What risks remain?
#
# Consider:
#
# - Bias
# - Explainability
# - Fairness
# - Maintenance costs
# - Scalability
#
# ---
#
# ## Question 5
#
# How would you improve the system in Version 2?
#
# Possible improvements:
#
# - Domain-specific training data
# - Transformer embeddings
# - RAG-based matching
# - Skill extraction pipelines
# - Human-in-the-loop validation
#
# ---
#
# # Final Deliverables
#
# ## Technical Report (Maximum 4 Pages)
#
# Include:
#
# 1. Human benchmark results
# 2. Embedding methodology
# 3. Similarity rankings
# 4. Adversarial testing results
# 5. Explainability analysis
# 6. Fairness analysis
# 7. Evaluation strategy
# 8. Final recommendation
#
# ---
#
# ## Executive Presentation (5 Minutes)
#
# Present:
#
# - Recommended embedding approach
# - Supporting evidence
# - Risks
# - Deployment strategy
# - Future roadmap
#
# ---
#
# # Bonus Challenge
#
# Management asks:
#
# > Why should we use Word2Vec, GloVe, or FastText when transformer-based embeddings exist?
#
# Compare:
#
# - TF-IDF
# - Word2Vec
# - GloVe
# - FastText
# - Transformer embeddings
#
# with respect to:
#
# - Accuracy
# - Interpretability
# - Cost
# - Latency
# - Deployment complexity
# - Privacy
# - Sustainability
#
# Provide a recommendation for a company with limited computational resources.
